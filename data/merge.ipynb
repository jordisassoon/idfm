# %%
import pandas as pd

# %%
df_2013 = pd.read_csv("trafic-annuel-entrant-par-station-du-reseau-ferre-2013.csv", sep='\t')
df_2013.to_csv("trafic-annuel-entrant-par-station-du-reseau-ferre-2013.csv", sep=",",index=False)
df_2013.head()
# Out:
#    Rang Réseau         Station  Trafic_2013 Correspondance_1 Correspondance_2  \
# 0    12  Métro           OPERA     12269711                3                7
# 1    13  Métro  HOTEL DE VILLE     11953352                1               11
# 2    19  Métro          NATION      9541406                1                2
# 3    25  Métro    SAINT-MICHEL      8797595        4   Paris                5
# 4    20  Métro    PALAIS-ROYAL      9385220                1                7
#
#   Correspondance_3  Correspondance_4  Correspondance_5  Ville  \
# 0                8               NaN               NaN  Paris
# 1              NaN               NaN               NaN  Paris
# 2                6               9.0               NaN  Paris
# 3             2013               NaN               NaN    NaN
# 4              NaN               NaN               NaN  Paris
#
#    Arrondissement pour Paris   Année
# 0                        9.0  2013.0
# 1                        4.0  2013.0
# ...

# %%
df = pd.read_csv("result_dataset.csv")
df = df.sort_values(by='Line')
df.to_csv("lol.csv", index=False)
df.head()
# Out:
#                       Station OpeningDate                               Town  \
# 58   Charles de Gaulle Étoile  1900-09-01  Paris 8th, Paris 16th, Paris 17th
# 322           Reuilly Diderot  1900-08-20                         Paris 12th
# 302             Porte Maillot  1900-07-19             Paris 16th, Paris 17th
# 295        Porte de Vincennes  1900-07-19             Paris 12th, Paris 20th
# 273           Pont de Neuilly  1937-04-29                  Neuilly-sur-Seine
#
#     Passengers Line
# 58     4291663    1
# 322    4580091    1
# 302    4138301    1
# 295    5446602    1
# 273    4809503    1
